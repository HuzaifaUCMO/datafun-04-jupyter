# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

# Load the Iris dataset
df = sns.load_dataset('iris')

# Display the first few rows of the dataset
df.head()

# Display the first 10 rows
print(df.head(10))

# Display the shape of the dataset
print(f"Shape of the dataset: {df.shape}")

# Display the data types of each column
print(f"Data types:\n{df.dtypes}")

# Display summary statistics for each column
df.describe()

# Plot histograms for numerical columns
df.hist(figsize=(10, 8), color='skyblue', edgecolor='black')
plt.suptitle("Histogram of Numerical Columns", fontsize=16)
plt.show()

# Display value counts for each categorical column
for col in df.select_dtypes(include=['object']).columns:
    print(f"Value counts for {col}:\n{df[col].value_counts()}\n")

# Visualize distribution of species
sns.countplot(x='species', data=df, palette='viridis')
plt.title("Distribution of Species", fontsize=16)
plt.show()

# Renaming columns for better readability
df.rename(columns={'sepal_length': 'Sepal Length', 'sepal_width': 'Sepal Width',
                   'petal_length': 'Petal Length', 'petal_width': 'Petal Width'}, inplace=True)

# Adding a new feature: Sepal Area
df['Sepal Area'] = df['Sepal Length'] * df['Sepal Width']
df.head()

# Pairplot to visualize relationships between features
sns.pairplot(df, hue='species')
plt.suptitle("Pairplot of Iris Dataset", y=1.02, fontsize=16)
plt.show()

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap", fontsize=16)
plt.show()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa
# Shape of the dataset: (150, 5)
# Data types:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object
# Value counts for species:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
# C:\Users\Nasira\AppData\Local\Temp\ipykernel_23748\3002457845.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='species', data=df, palette='viridis')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 55
#      53 # Correlation heatmap
#      54 plt.figure(figsize=(8, 6))
# ---> 55 sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
#      56 plt.title("Correlation Heatmap", fontsize=16)
#      57 plt.show()
#
# File c:\Users\Nasira\datafun-04-jupyter\.venv\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Nasira\datafun-04-jupyter\.venv\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\Nasira\datafun-04-jupyter\.venv\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\Nasira\datafun-04-jupyter\.venv\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'setosa'
